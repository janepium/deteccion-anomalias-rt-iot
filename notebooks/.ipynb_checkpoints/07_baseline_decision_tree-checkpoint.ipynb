# %% [markdown]
# # 07 — Baseline Decision Tree
#
# **Responsable:** Edwin.
#
# **Objetivo:** entrenar el primer modelo baseline del proyecto (Decision Tree) sobre
# `data/processed/dataset_limpio.csv`, siguiendo el protocolo ya acordado por el equipo en
# `reports/decisiones_preparacion.md` (secciones H e I):
#
# - Comparar una variante **con** variables leaky (`id.orig_p`, `id.resp_p`, `proto`, `service`)
#   y una variante **sin** ellas.
# - `class_weight="balanced"` para manejar el desbalance de clases (sin SMOTE).
# - Split 80/20 estratificado + `StratifiedKFold` sobre train (test reservado para el reporte final).
# - `random_state=42` en todo (convención del equipo).
# - Vigilar la señal de alarma documentada: **F1 ≈ 1.0, sobre todo con leaky, indica fuga de datos.**

# %%
import os
import json
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, label_binarize
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import (
    classification_report, confusion_matrix, accuracy_score,
    f1_score, precision_score, recall_score, average_precision_score,
)

RANDOM_STATE = 42
sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## 1. Carga del dataset limpio

# %%
DATA_PATH = "../data/processed/dataset_limpio.csv"
df = pd.read_csv(DATA_PATH, index_col=0)

print("Shape:", df.shape)
print("Nulos totales:", df.isna().sum().sum())
print()
print(df["Attack_type"].value_counts())

assert df.isna().sum().sum() == 0, "Se esperaba un dataset sin nulos (ya validado en 03/05)."
# Out:
# Shape: (117922, 37)
# Nulos totales: 0
#
# Attack_type
# DOS_SYN_Hping                 90089
# Thing_Speak                    7654
# ARP_poisioning                 7625
# MQTT_Publish                   4142
# NMAP_UDP_SCAN                  2584
# NMAP_XMAS_TREE_SCAN            2010
# NMAP_OS_DETECTION              2000
# NMAP_TCP_scan                  1002
# DDOS_Slowloris                  533
# Wipro_bulb                      219
# Metasploit_Brute_Force_SSH       36
# NMAP_FIN_SCAN                    28
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Variables leaky vs no-leaky
#
# Siguiendo `docs/validacion_variables.md` y `reports/decisiones_preparacion.md` (H1), las
# columnas con riesgo de fuga de información son `id.orig_p`, `id.resp_p`, `proto` y `service`
# (evidencia: `id.resp_p` correlaciona >0.9 con `fwd_pkts_payload.avg`, es decir el puerto
# "predice" el payload).

# %%
TARGET = "Attack_type"
LEAKY_NUM = ["id.orig_p", "id.resp_p"]
LEAKY_CAT = ["proto", "service"]
BASE_NUM = [c for c in df.columns if c not in [TARGET, *LEAKY_NUM, *LEAKY_CAT]]

print(f"Features base (no leaky): {len(BASE_NUM)}")
print(f"Features leaky numericas: {LEAKY_NUM}")
print(f"Features leaky categoricas: {LEAKY_CAT}")

X = df.drop(columns=[TARGET])
y = df[TARGET]
# Out:
# Features base (no leaky): 32
# Features leaky numericas: ['id.orig_p', 'id.resp_p']
# Features leaky categoricas: ['proto', 'service']

# %% [markdown]
# ## 3. Split 80/20 estratificado (compartido por ambas variantes)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=RANDOM_STATE, stratify=y
)
print("Train:", X_train.shape, "Test:", X_test.shape)
print()
print("Proporcion de clases en train:")
print(y_train.value_counts(normalize=True).round(4))
# Out:
# Train: (94337, 36) Test: (23585, 36)
#
# Proporcion de clases en train:
# Attack_type
# DOS_SYN_Hping                 0.7640
# Thing_Speak                   0.0649
# ARP_poisioning                0.0647
# MQTT_Publish                  0.0351
# NMAP_UDP_SCAN                 0.0219
# NMAP_XMAS_TREE_SCAN           0.0170
# NMAP_OS_DETECTION             0.0170
# NMAP_TCP_scan                 0.0085
# DDOS_Slowloris                0.0045
# Wipro_bulb                    0.0019
# Metasploit_Brute_Force_SSH    0.0003
# NMAP_FIN_SCAN                 0.0002
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4. `build_preprocessor(include_leaky)` + pipeline
#
# Implementa el toggle mencionado (pero nunca construido) en `reports/decisiones_preparacion.md`
# H1. El split ya ocurrio arriba, y el `OneHotEncoder` se ajusta solo sobre train dentro del
# `Pipeline` (orden anti-leakage, protocolo I3).
#
# El arbol se deja **sin restriccion de profundidad** a proposito: es un baseline diagnostico,
# y limitar la profundidad ocultaria la senal de sobreajuste/leakage que el protocolo pide vigilar.

# %%
def build_preprocessor(include_leaky: bool) -> ColumnTransformer:
    if include_leaky:
        num_cols = BASE_NUM + LEAKY_NUM
        cat_cols = LEAKY_CAT
    else:
        num_cols = BASE_NUM
        cat_cols = []

    transformers = [("num", "passthrough", num_cols)]
    if cat_cols:
        transformers.append(("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols))
    return ColumnTransformer(transformers)


def build_pipeline(include_leaky: bool) -> Pipeline:
    return Pipeline([
        ("prep", build_preprocessor(include_leaky)),
        ("clf", DecisionTreeClassifier(class_weight="balanced", random_state=RANDOM_STATE)),
    ])


VARIANTS = {"con_leaky": True, "sin_leaky": False}
pipelines = {name: build_pipeline(inc) for name, inc in VARIANTS.items()}

# %% [markdown]
# ## 5. Piso de referencia (`DummyClassifier`)
#
# Protocolo I2: contextualizar que accuracy es "trivial" antes de evaluar el arbol.

# %%
dummy = DummyClassifier(strategy="most_frequent", random_state=RANDOM_STATE)
t0 = time.perf_counter()
dummy.fit(X_train, y_train)
dummy_fit_time = time.perf_counter() - t0

y_pred_dummy = dummy.predict(X_test)
dummy_metrics = {
    "accuracy": accuracy_score(y_test, y_pred_dummy),
    "f1_macro": f1_score(y_test, y_pred_dummy, average="macro", zero_division=0),
    "f1_weighted": f1_score(y_test, y_pred_dummy, average="weighted", zero_division=0),
    "recall_macro": recall_score(y_test, y_pred_dummy, average="macro", zero_division=0),
    "fit_time_s": dummy_fit_time,
}
dummy_metrics
# Out:
# {'accuracy': 0.7639601441594234,
#  'f1_macro': 0.07218229454606638,
#  'f1_weighted': 0.66173275376605,
#  'recall_macro': 0.08333333333333333,
#  'fit_time_s': 0.04965020000236109}

# %% [markdown]
# ## 6. Entrenamiento de ambas variantes + tiempos de `fit`

# %%
fit_times = {}
for name, pipe in pipelines.items():
    t0 = time.perf_counter()
    pipe.fit(X_train, y_train)
    fit_times[name] = time.perf_counter() - t0
    print(f"{name}: fit_time = {fit_times[name]:.3f} s")
# Out:
# con_leaky: fit_time = 1.097 s
# sin_leaky: fit_time = 0.641 s

# %% [markdown]
# ## 7. Validacion cruzada estratificada (`StratifiedKFold`)
#
# 5 folds sobre el train (protocolo I1). `return_train_score=True` da directamente la
# comparacion train-vs-validacion para el diagnostico de sobreajuste; `cross_validate` ya
# registra `fit_time`/`score_time` por fold.

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
scoring = ["accuracy", "f1_macro", "f1_weighted", "precision_macro", "recall_macro"]

cv_results = {}
for name, inc in VARIANTS.items():
    pipe = build_pipeline(inc)  # instancia fresca, no reusar el arbol ya ajustado
    cv_results[name] = cross_validate(
        pipe, X_train, y_train, cv=skf, scoring=scoring,
        return_train_score=True, n_jobs=-1,
    )

cv_summary_rows = []
for name, res in cv_results.items():
    row = {"variante": name}
    for metric in scoring:
        row[f"cv_val_{metric}_mean"] = res[f"test_{metric}"].mean()
        row[f"cv_val_{metric}_std"] = res[f"test_{metric}"].std()
        row[f"cv_train_{metric}_mean"] = res[f"train_{metric}"].mean()
    row["cv_fit_time_mean_s"] = res["fit_time"].mean()
    cv_summary_rows.append(row)

cv_summary = pd.DataFrame(cv_summary_rows).set_index("variante")
cv_summary
# Out:
#            cv_val_accuracy_mean  cv_val_accuracy_std  cv_train_accuracy_mean  \
# variante
# con_leaky              0.997286             0.000218                0.999973
# sin_leaky              0.994944             0.000438                0.998105
#
#            cv_val_f1_macro_mean  cv_val_f1_macro_std  cv_train_f1_macro_mean  \
# variante
# con_leaky              0.956808             0.020092                0.998806
# sin_leaky              0.933277             0.008984                0.994177
#
#            cv_val_f1_weighted_mean  cv_val_f1_weighted_std  \
# variante
# con_leaky                 0.997289                0.000212
# sin_leaky                 0.994986                0.000439
#
#            cv_train_f1_weighted_mean  cv_val_precision_macro_mean  \
# variante
# con_leaky                   0.999974                     0.958600
# sin_leaky                   0.998127                     0.925862
#
#            cv_val_precision_macro_std  cv_train_precision_macro_mean  \
# ...

# %% [markdown]
# ## 8. Evaluacion en el test reservado

# %%
def evaluate_on_test(pipe, name):
    y_pred = pipe.predict(X_test)
    y_proba = pipe.predict_proba(X_test)
    classes = pipe.named_steps["clf"].classes_
    y_test_bin = label_binarize(y_test, classes=classes)
    pr_auc = average_precision_score(y_test_bin, y_proba, average="macro")

    metrics = {
        "accuracy": accuracy_score(y_test, y_pred),
        "f1_macro": f1_score(y_test, y_pred, average="macro", zero_division=0),
        "f1_weighted": f1_score(y_test, y_pred, average="weighted", zero_division=0),
        "precision_macro": precision_score(y_test, y_pred, average="macro", zero_division=0),
        "recall_macro": recall_score(y_test, y_pred, average="macro", zero_division=0),
        "pr_auc_macro": pr_auc,
    }
    print(f"\n=== {name} - classification_report (test) ===")
    print(classification_report(y_test, y_pred, zero_division=0))
    return metrics, y_pred, classes

test_metrics = {}
test_preds = {}
for name, pipe in pipelines.items():
    metrics, y_pred, classes = evaluate_on_test(pipe, name)
    test_metrics[name] = metrics
    test_preds[name] = (y_pred, classes)
# Out:
# === con_leaky - classification_report (test) ===
#                             precision    recall  f1-score   support
#
#             ARP_poisioning       0.99      0.98      0.98      1525
#             DDOS_Slowloris       0.98      1.00      0.99       107
#              DOS_SYN_Hping       1.00      1.00      1.00     18018
#               MQTT_Publish       1.00      1.00      1.00       828
# Metasploit_Brute_Force_SSH       0.88      1.00      0.93         7
#              NMAP_FIN_SCAN       1.00      1.00      1.00         6
#          NMAP_OS_DETECTION       1.00      1.00      1.00       400
#              NMAP_TCP_scan       1.00      1.00      1.00       200
#              NMAP_UDP_SCAN       0.99      0.99      0.99       517
#        NMAP_XMAS_TREE_SCAN       1.00      1.00      1.00       402
#                Thing_Speak       0.98      0.99      0.98      1531
#                 Wipro_bulb       0.98      0.95      0.97        44
#
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
for ax, (name, (y_pred, classes)) in zip(axes, test_preds.items()):
    cm = confusion_matrix(y_test, y_pred, labels=classes)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes,
                yticklabels=classes, ax=ax, cbar=False)
    ax.set_title(f"Matriz de confusion (test) - {name}")
    ax.set_xlabel("Predicho")
    ax.set_ylabel("Real")
    ax.tick_params(axis="x", rotation=90)
    ax.tick_params(axis="y", rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Tabla comparativa final

# %%
rows = [{
    "variante": "dummy_floor",
    "accuracy": dummy_metrics["accuracy"],
    "f1_macro": dummy_metrics["f1_macro"],
    "f1_weighted": dummy_metrics["f1_weighted"],
    "recall_macro": dummy_metrics["recall_macro"],
    "pr_auc_macro": np.nan,
    "cv_f1_macro_mean": np.nan,
    "cv_f1_macro_std": np.nan,
    "fit_time_s": dummy_metrics["fit_time_s"],
    "tree_depth": np.nan,
    "tree_leaves": np.nan,
}]
for name in VARIANTS:
    clf = pipelines[name].named_steps["clf"]
    rows.append({
        "variante": name,
        "accuracy": test_metrics[name]["accuracy"],
        "f1_macro": test_metrics[name]["f1_macro"],
        "f1_weighted": test_metrics[name]["f1_weighted"],
        "recall_macro": test_metrics[name]["recall_macro"],
        "pr_auc_macro": test_metrics[name]["pr_auc_macro"],
        "cv_f1_macro_mean": cv_summary.loc[name, "cv_val_f1_macro_mean"],
        "cv_f1_macro_std": cv_summary.loc[name, "cv_val_f1_macro_std"],
        "fit_time_s": fit_times[name],
        "tree_depth": clf.get_depth(),
        "tree_leaves": clf.get_n_leaves(),
    })

comparison = pd.DataFrame(rows).set_index("variante")
comparison.round(4)
# Out:
#              accuracy  f1_macro  f1_weighted  recall_macro  pr_auc_macro  \
# variante
# dummy_floor    0.7640    0.0722       0.6617        0.0833           NaN
# con_leaky      0.9975    0.9871       0.9975        0.9924        0.9864
# sin_leaky      0.9957    0.9712       0.9957        0.9825        0.9696
#
#              cv_f1_macro_mean  cv_f1_macro_std  fit_time_s  tree_depth  \
# variante
# dummy_floor               NaN              NaN      0.0497         NaN
# con_leaky              0.9568           0.0201      1.0974        33.0
# sin_leaky              0.9333           0.0090      0.6408        24.0
#
#              tree_leaves
# variante
# dummy_floor          NaN
# con_leaky          306.0
# sin_leaky          360.0

# %% [markdown]
# ## 10. Importancia de variables (feature importance)
#
# Si las columnas leaky dominan el ranking en la variante *con leaky*, es otra confirmacion
# (ademas de la metrica) de que estan "haciendo trampa" (H2).

# %%
def get_feature_importances(pipe):
    prep = pipe.named_steps["prep"]
    clf = pipe.named_steps["clf"]
    names = [n.split("__", 1)[-1] for n in prep.get_feature_names_out()]
    return pd.Series(clf.feature_importances_, index=names).sort_values(ascending=False)

importances = {name: get_feature_importances(pipe) for name, pipe in pipelines.items()}

fig, axes = plt.subplots(1, 2, figsize=(16, 7))
for ax, (name, imp) in zip(axes, importances.items()):
    top = imp.head(15)[::-1]
    ax.barh(top.index, top.values, color="#4C72B0")
    ax.set_title(f"Top 15 feature importance - {name}")
    ax.set_xlabel("Importancia (Gini)")
plt.tight_layout()
plt.show()

for name, imp in importances.items():
    print(f"\nTop 10 - {name}")
    print(imp.head(10).round(4))
# Out:
# Top 10 - con_leaky
# fwd_last_window_size     0.2040
# id.resp_p                0.1527
# flow_pkts_per_sec        0.0975
# fwd_URG_flag_count       0.0907
# service_mqtt             0.0907
# fwd_pkts_payload.avg     0.0632
# service_-                0.0594
# service_http             0.0555
# flow_pkts_payload.max    0.0463
# flow_duration            0.0372
# dtype: float64
#
# Top 10 - sin_leaky
# fwd_last_window_size     0.2247
# fwd_PSH_flag_count       0.1362
# flow_pkts_per_sec        0.0987
# fwd_URG_flag_count       0.0913
# flow_pkts_payload.max    0.0791
# flow_pkts_payload.min    0.0731
# flow_FIN_flag_count      0.0713
# bwd_init_window_size     0.0585
# bwd_pkts_tot             0.0312
# fwd_data_pkts_tot        0.0217
# dtype: float64

# %% [markdown]
# ## 11. Diagnostico de sobreajuste (train vs CV vs test)

# %%
overfit_rows = []
for name in VARIANTS:
    clf = pipelines[name].named_steps["clf"]
    train_pred = pipelines[name].predict(X_train)
    overfit_rows.append({
        "variante": name,
        "train_f1_macro": f1_score(y_train, train_pred, average="macro", zero_division=0),
        "cv_val_f1_macro": cv_summary.loc[name, "cv_val_f1_macro_mean"],
        "test_f1_macro": test_metrics[name]["f1_macro"],
        "tree_depth": clf.get_depth(),
        "tree_leaves": clf.get_n_leaves(),
    })

overfit_df = pd.DataFrame(overfit_rows).set_index("variante")
overfit_df["gap_train_vs_test"] = overfit_df["train_f1_macro"] - overfit_df["test_f1_macro"]
overfit_df.round(4)
# Out:
#            train_f1_macro  cv_val_f1_macro  test_f1_macro  tree_depth  \
# variante
# con_leaky          0.9984           0.9568         0.9871          33
# sin_leaky          0.9938           0.9333         0.9712          24
#
#            tree_leaves  gap_train_vs_test
# variante
# con_leaky          306             0.0114
# sin_leaky          360             0.0226

# %% [markdown]
# ## 12. Guardado del modelo baseline\n\nSe persiste la variante **sin leaky** (la recomendada por el equipo, `docs/encoding.md`).

# %%
MODELS_DIR = "../models"
os.makedirs(MODELS_DIR, exist_ok=True)

model_path = os.path.join(MODELS_DIR, "decision_tree_baseline.pkl")
joblib.dump(pipelines["sin_leaky"], model_path)
print(f"Modelo guardado en {model_path}")

loaded = joblib.load(model_path)
reload_pred = loaded.predict(X_test)
assert accuracy_score(y_test, reload_pred) == test_metrics["sin_leaky"]["accuracy"]
print("Recarga verificada: metricas consistentes con el modelo entrenado en este notebook.")
# Out:
# Modelo guardado en ../models\decision_tree_baseline.pkl
# Recarga verificada: metricas consistentes con el modelo entrenado en este notebook.

# %% [markdown]
# ## 13. Resumen numerico (para trazabilidad de `docs/baseline_decision_tree.md`)

# %%
summary_dict = {
    "comparison_table": comparison.round(4).to_dict(orient="index"),
    "cv_summary": cv_summary.round(4).to_dict(orient="index"),
    "overfit": overfit_df.round(4).to_dict(orient="index"),
    "top_importances_sin_leaky": importances["sin_leaky"].head(10).round(4).to_dict(),
    "top_importances_con_leaky": importances["con_leaky"].head(10).round(4).to_dict(),
}
print(json.dumps(summary_dict, indent=2, ensure_ascii=False))
# Out:
# {
#   "comparison_table": {
#     "dummy_floor": {
#       "accuracy": 0.764,
#       "f1_macro": 0.0722,
#       "f1_weighted": 0.6617,
#       "recall_macro": 0.0833,
#       "pr_auc_macro": NaN,
#       "cv_f1_macro_mean": NaN,
#       "cv_f1_macro_std": NaN,
#       "fit_time_s": 0.0497,
#       "tree_depth": NaN,
#       "tree_leaves": NaN
#     },
#     "con_leaky": {
#       "accuracy": 0.9975,
#       "f1_macro": 0.9871,
#       "f1_weighted": 0.9975,
#       "recall_macro": 0.9924,
#       "pr_auc_macro": 0.9864,
#       "cv_f1_macro_mean": 0.9568,
#       "cv_f1_macro_std": 0.0201,
#       "fit_time_s": 1.0974,
#       "tree_depth": 33.0,
#       "tree_leaves": 306.0
#     },
#     "sin_leaky": {
#       "accuracy": 0.9957,
#       "f1_macro": 0.9712,
#       "f1_weighted": 0.9957,
#       "recall_macro": 0.9825,
#       "pr_auc_macro": 0.9696,
#       "cv_f1_macro_mean": 0.9333,
#       "cv_f1_macro_std": 0.009,
#       "fit_time_s": 0.6408,
#       "tree_depth": 24.0,
# ...

# %% [markdown]
# ## 14. Conclusiones
#
# ### ¿Qué desempeño obtiene el baseline?
#
# La variante **sin leaky** (la guardada como modelo oficial) obtiene en el test reservado:
# accuracy 0.9957, F1-macro 0.9712, F1-weighted 0.9957, recall-macro 0.9825, PR-AUC-macro
# 0.9696. La medida más honesta es la de validación cruzada (5-fold estratificado sobre train,
# no toca el test): F1-macro promedio **0.9333 ± 0.009**. Comparado contra el piso trivial
# (`DummyClassifier` que siempre predice `DOS_SYN_Hping`: accuracy 0.764 pero F1-macro apenas
# **0.0722**), el baseline aprende señal real y no es solo un artefacto del desbalance de clases.
#
# ### ¿Existe diferencia entre usar variables leaky y no usarlas?
#
# Sí, una diferencia moderada y consistente (no catastrófica): la variante **con leaky** es
# sistemáticamente mejor — F1-macro test 0.9871 vs 0.9712 (+1.6 pp), F1-macro CV 0.9568±0.0201
# vs 0.9333±0.009 (+2.3 pp), recall-macro 0.9924 vs 0.9825, PR-AUC-macro 0.9864 vs 0.9696.
# `id.resp_p` entra como la **2ª variable más importante** (15.3%) en cuanto se incluye, y los
# dummies de `service`/`proto` (`service_mqtt`, `service_-`, `service_http`) también aparecen en
# su top 10 — confirma que el árbol efectivamente explota esas columnas, tal como advertía
# `reports/decisiones_preparacion.md` (H1). Ninguna variante llega a F1≈1.0 exacto, así que la
# señal de alarma extrema de H2 no se dispara con fuerza, pero la mejora sistemática + la alta
# importancia individual de `id.resp_p` es evidencia suficiente de que esas columnas aportan
# información que un IDS real (sin acceso a puertos/servicio de la sesión) no tendría. Por eso
# se guarda como modelo oficial la variante **sin leaky**, siguiendo la recomendación de
# `docs/encoding.md`.
#
# ### ¿Qué variables fueron las más importantes?
#
# **Sin leaky** (top 5): `fwd_last_window_size` (22.5%), `fwd_PSH_flag_count` (13.6%),
# `flow_pkts_per_sec` (9.9%), `fwd_URG_flag_count` (9.1%), `flow_pkts_payload.max` (7.9%).
#
# **Con leaky** (top 5): `fwd_last_window_size` (20.4%), `id.resp_p` (15.3%),
# `flow_pkts_per_sec` (9.8%), `fwd_URG_flag_count` (9.1%), `service_mqtt` (9.1%).
#
# `fwd_last_window_size` domina en ambas variantes — el tamaño de la última ventana TCP es, con
# diferencia, la señal más discriminante entre tipos de tráfico/ataque en este dataset.
#
# ### ¿El modelo presenta señales de sobreajuste?
#
# Sí, claras. El árbol se deja **sin poda a propósito** (para exponer esta señal): profundidad
# 24 / 360 hojas (sin leaky) y profundidad 33 / 306 hojas (con leaky). En CV, el F1-macro de
# **train** es 0.994–0.999 mientras que el de **validación** es 0.933–0.957 — una brecha de
# 4 a 6 puntos porcentuales, típica de un árbol sin regularizar que memoriza el train. En el
# holdout de test la brecha es menor (train 0.994 vs test 0.971 en la variante sin leaky) porque
# train y test comparten una distribución muy similar; la comparación por CV es la más honesta y
# sí muestra sobreajuste. Próximo paso natural: `max_depth`/`min_samples_leaf`, o pasar a un
# modelo ensemble (Random Forest) para reducir varianza.
#
# ### ¿Qué dificultades aparecieron durante el entrenamiento?
#
# - El entorno no tenía `scikit-learn`, `joblib`, `matplotlib` ni `seaborn` instalados (solo
#   pandas/numpy/jupyter) — hubo que instalarlos antes de poder ejecutar el notebook
#   (`scikit-learn` 1.9.0, lo que además actualizó `numpy` de 1.26.4 a 2.5.1).
# - Las clases extremadamente raras (`NMAP_FIN_SCAN` = 28 filas totales,
#   `Metasploit_Brute_Force_SSH` = 36) quedan con muy pocas muestras por fold en el 5-fold CV
#   (~5-6 en train por fold); `StratifiedKFold` lo maneja sin fallar, pero el resultado en esas
#   clases es más inestable (se refleja en la desviación estándar de la CV).
# - `cross_validate(..., n_jobs=-1)` en Windows generó ruido inofensivo del *resource tracker*
#   de `joblib`/`loky` (`KeyError` en la limpieza de carpetas de *memmapping* al finalizar) — no
#   afectó el resultado (el notebook terminó con éxito), pero queda documentado por si vuelve a
#   aparecer en notebooks futuros que usen paralelismo.
# - Un árbol sin límite de profundidad es sensible a la partición de datos exacta, lo que se
#   traduce directamente en la brecha train/CV descrita arriba — queda como decisión abierta para
#   el siguiente modelo si conviene podar el árbol o pasar a un ensemble.
